# %%
#we use DROPOUT this is used for improving accuracy and avoiding the overfitting

# %%
#libraries
import pandas as pd 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
#Load dataset
dataset = pd.read_csv('customer_churn_dataset_10000.csv')
dataset.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   36       9   75545.78              3          0
# 1          659   54       5  146329.55              4          0
# 2          437   39       2   36866.73              1          0
# 3          805   49       7   59527.03              1          1
# 4          735   58       2   42917.82              2          0
#
#    IsActiveMember  EstimatedSalary  Exited
# 0               1        102407.92       0
# 1               0        145672.18       0
# 2               1        169330.69       0
# 3               1        123704.11       0
# 4               0         77518.87       1

# %%
#Check is there any null value
dataset.isnull().sum()
# Out:
# CreditScore        0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
input_data= dataset.iloc[:, :-1]   # all features
output_data= dataset.iloc[:, -1]    # only last column (labels)

# %%
#Scalling of data
ss = StandardScaler()
input_data = pd.DataFrame(ss.fit_transform(input_data), columns = input_data.columns)
input_data
# Out:
#       CreditScore       Age    Tenure   Balance  NumOfProducts  HasCrCard  \
# 0        0.056608 -0.377436  1.462972 -0.472352       0.473206  -0.924632
# 1        0.337459  0.968975  0.171535  0.740119       1.335147  -0.924632
# 2       -1.221261 -0.153035 -0.797043 -1.134894      -1.250677  -0.924632
# 3        1.362563  0.594972  0.817254 -0.746741      -1.250677   1.081512
# 4        0.871075  1.268177 -0.797043 -1.031244      -0.388735  -0.924632
# ...           ...       ...       ...       ...            ...        ...
# 9995    -1.481048 -1.275044 -1.442761 -1.713962       1.335147   1.081512
# 9996    -1.396793  1.118576  0.171535 -0.407526      -0.388735   1.081512
# 9997    -1.467006 -0.826240 -0.474183 -0.827844      -0.388735  -0.924632
# 9998    -1.495091 -1.499446 -0.797043  1.589259      -1.250677  -0.924632
# 9999     0.021502 -1.723847 -0.151324  0.465493      -1.250677  -0.924632
#
#       IsActiveMember  EstimatedSalary
# 0           1.062980        -0.132003
# 1          -0.940752         0.685194
# 2           1.062980         1.132069
# 3           1.062980         0.270250
# 4          -0.940752        -0.602121
# ...              ...              ...
# 9995        1.062980         0.712227
# 9996        1.062980        -1.208781
# 9997        1.062980         0.195041
# 9998        1.062980        -0.179345
# 9999       -0.940752         0.059724
#
# [10000 rows x 8 columns]

# %%
input_data.shape
# Out:
# (10000, 8)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    input_data,
    output_data,
    test_size=0.2,
    random_state=10
)

# %%
X_train.shape
# Out:
# (8000, 8)

# %%
X_test.shape
# Out:
# (2000, 8)

# %%
import tensorflow
from keras.regularizers import L2
from keras.layers import Dense, BatchNormalization, Dropout
from keras.models import Sequential
from keras.callbacks import EarlyStopping

# %%
ann = Sequential()

ann.add(Dense(6, input_dim=8, activation="relu", kernel_regularizer=L2(l2=0.01)))

ann.add(Dense(4, activation="relu",kernel_regularizer=L2(l2=0.01)))

ann.add(Dense(2, activation="relu",kernel_regularizer=L2(l2=0.01)))
ann.add(Dropout(0.3))
ann.add(Dense(1, activation="sigmoid"))
# Out:
# C:\Users\Muzamil Hussain\AppData\Local\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
ann.compile(optimizer="adam", loss="binary_crossentropy", metrics=['accuracy'])

# %%
ann.fit(X_train, y_train, batch_size=100, epochs=50, validation_data = (X_test, y_test), callbacks = EarlyStopping())
# Out:
# Epoch 1/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.5253 - loss: 0.8928 - val_accuracy: 0.5320 - val_loss: 0.8139
# Epoch 2/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5426 - loss: 0.8120 - val_accuracy: 0.5870 - val_loss: 0.7879
# Epoch 3/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5669 - loss: 0.7862 - val_accuracy: 0.6110 - val_loss: 0.7706
# Epoch 4/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5826 - loss: 0.7701 - val_accuracy: 0.6225 - val_loss: 0.7582
# Epoch 5/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5850 - loss: 0.7601 - val_accuracy: 0.6140 - val_loss: 0.7483
# Epoch 6/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5913 - loss: 0.7483 - val_accuracy: 0.6205 - val_loss: 0.7403
# Epoch 7/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6087 - loss: 0.7388 - val_accuracy: 0.6245 - val_loss: 0.7330
# Epoch 8/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6019 - loss: 0.7332 - val_accuracy: 0.6315 - val_loss: 0.7264
# Epoch 9/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6220 - loss: 0.7241 - val_accuracy: 0.6365 - val_loss: 0.7198
# Epoch 10/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6354 - loss: 0.7186 - val_accuracy: 0.6525 - val_loss: 0.7150
# Epoch 11/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6382 - loss: 0.7131 - val_accuracy: 0.6645 - val_loss: 0.7110
# Epoch 12/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6399 - loss: 0.7099 - val_accuracy: 0.6585 - val_loss: 0.7067
# Epoch 13/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6351 - loss: 0.7065 - val_accuracy: 0.6485 - val_loss: 0.7033
# Epoch 14/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6329 - loss: 0.7028 - val_accuracy: 0.6555 - val_loss: 0.7000
# Epoch 15/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6349 - loss: 0.6995 - val_accuracy: 0.6555 - val_loss: 0.6965
# Epoch 16/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6404 - loss: 0.6961 - val_accuracy: 0.6760 - val_loss: 0.6936
# Epoch 17/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6489 - loss: 0.6934 - val_accuracy: 0.6765 - val_loss: 0.6904
# Epoch 18/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6466 - loss: 0.6919 - val_accuracy: 0.6975 - val_loss: 0.6860
# Epoch 19/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6521 - loss: 0.6871 - val_accuracy: 0.6875 - val_loss: 0.6828
# Epoch 20/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6504 - loss: 0.6856 - val_accuracy: 0.7005 - val_loss: 0.6796
# Epoch 21/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6538 - loss: 0.6809 - val_accuracy: 0.6970 - val_loss: 0.6763
# Epoch 22/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6520 - loss: 0.6782 - val_accuracy: 0.7045 - val_loss: 0.6726
# Epoch 23/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6555 - loss: 0.6760 - val_accuracy: 0.6900 - val_loss: 0.6708
# Epoch 24/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6607 - loss: 0.6739 - val_accuracy: 0.7155 - val_loss: 0.6652
# Epoch 25/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6630 - loss: 0.6731 - val_accuracy: 0.6950 - val_loss: 0.6627
# Epoch 26/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6654 - loss: 0.6699 - val_accuracy: 0.6985 - val_loss: 0.6582
# Epoch 27/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6694 - loss: 0.6667 - val_accuracy: 0.7065 - val_loss: 0.6557
# Epoch 28/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6644 - loss: 0.6682 - val_accuracy: 0.7105 - val_loss: 0.6528
# Epoch 29/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6715 - loss: 0.6638 - val_accuracy: 0.7295 - val_loss: 0.6497
# Epoch 30/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6750 - loss: 0.6613 - val_accuracy: 0.7360 - val_loss: 0.6483
# Epoch 31/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6786 - loss: 0.6579 - val_accuracy: 0.7035 - val_loss: 0.6469
# Epoch 32/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6737 - loss: 0.6588 - val_accuracy: 0.7175 - val_loss: 0.6454
# Epoch 33/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6764 - loss: 0.6580 - val_accuracy: 0.7230 - val_loss: 0.6430
# Epoch 34/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6737 - loss: 0.6562 - val_accuracy: 0.7310 - val_loss: 0.6413
# Epoch 35/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6759 - loss: 0.6578 - val_accuracy: 0.7295 - val_loss: 0.6408
# Epoch 36/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6749 - loss: 0.6573 - val_accuracy: 0.7170 - val_loss: 0.6402
# Epoch 37/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6762 - loss: 0.6563 - val_accuracy: 0.7230 - val_loss: 0.6387
# Epoch 38/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6770 - loss: 0.6556 - val_accuracy: 0.7295 - val_loss: 0.6380
# Epoch 39/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6796 - loss: 0.6528 - val_accuracy: 0.7235 - val_loss: 0.6371
# Epoch 40/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6811 - loss: 0.6508 - val_accuracy: 0.7370 - val_loss: 0.6371

# %%
train_accuracy = ann.history.history["accuracy"]
test_accuracy = ann.history.history["val_accuracy"]

# %%
len(test_accuracy)
# Out:
# 40

# %%
epochs = range(1, len(train_accuracy) + 1)

plt.plot(epochs, train_accuracy)
plt.plot(epochs, test_accuracy)
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.show()

# %%
prd = ann.predict(X_test)
prd_data = []
for i in prd:
    if i[0] > 0.5:
        prd_data.append(1)
    else: 
        prd_data.append(0)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
prd1 = ann.predict(X_train)
prd_data1 = []
for i in prd1:
    if i[0] > 0.5:
        prd_data1.append(1)
    else: 
        prd_data1.append(0)
# Out:
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, prd_data)*100
# Out:
# 73.7

# %%
accuracy_score(y_train, prd_data1)*100
# Out:
# 74.3
